# %%
# Data Handling
import pandas as pd

# Date time format
import datetime as dt

# Visualize Results
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# Pull in financial information
import yfinance as yf 

from pathlib import Path

# %% [markdown]
# ### First 2 cells are commented out for efficiency.
# Cell 1 initated all tickers in the Dow Jones Industrial Average, to be organized in a list to be used in a loop
#
# For loop iterates through the tickers list and pulls their fundamental information in dictionary format
#
# Cell 2 - Saves this information into a CSV file to be read in, saving about 5 minutes of load time for the API to pull all data

# %%
# List all tickers in the Dow30
# tickers = ('AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH','CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW')

# For loop to read in all tickers into the API and pull their fundamental information
# '.info' pull all the fundamental information into a dictionary

# fundamental_info = []
# for ticker in tickers:
#     fundamental_info.append(yf.Ticker(ticker).info)

# fundamental_info

# %%
# Save the DataFrame to the `Resources` folder

# fundamental_info_df.to_csv("./Resources/fundamental_info_df.csv")
# fundamental_info

# %%
# Use the Pathlib libary to set the path to the CSV
csv_path = Path("./Resources/fundamental_info_df.csv")

# Use the file path to read the CSV into a DataFrame and display a few rows
fundamental_info_df = pd.read_csv(csv_path, index_col = 'symbol')
fundamental_info_df
# Out:
#                zip                  sector  fullTimeEmployees  \
# symbol
# AXP          10285      Financial Services            64000.0
# AMGN    91320-1799              Healthcare            24200.0
# AAPL         95014              Technology           154000.0
# BA      60606-1596             Industrials           142000.0
# CAT          60015             Industrials           107700.0
# CSCO         95134              Technology            79500.0
# CVX     94583-2324                  Energy            42595.0
# GS           10282      Financial Services            47000.0
# HD           30339       Consumer Cyclical           500000.0
# HON          28202             Industrials            99000.0
# IBM          10504              Technology           282100.0
# INTC    95054-1549              Technology           121100.0
# JNJ          08933              Healthcare           141700.0
# KO           30313      Consumer Defensive            79000.0
# JPM          10179      Financial Services           278494.0
# MCD          60607       Consumer Cyclical           100000.0
# MMM     55144-1000             Industrials            95000.0
# MRK          07033              Healthcare            67000.0
# MSFT    98052-6399              Technology           221000.0
# NKE     97005-6453       Consumer Cyclical            79100.0
# PG           45202      Consumer Defensive                NaN
# TRV          10017      Financial Services            30184.0
# UNH          55343              Healthcare           350000.0
# CRM          94105              Technology            77810.0
# VZ           10036  Communication Services           119400.0
# V       94128-8999      Financial Services            21500.0
# WBA          60015              Healthcare           315000.0
# WMT          72716      Consumer Defensive          2300000.0
# DIS          91521  Communication Services           152000.0
# DOW          48674         Basic Materials            35700.0
#
#                                       longBusinessSummary           city  \
# symbol
# AXP     American Express Company, together with its su...       New York
# AMGN    Amgen Inc. discovers, develops, manufactures, ...  Thousand Oaks
# AAPL    Apple Inc. designs, manufactures, and markets ...      Cupertino
# BA      The Boeing Company, together with its subsidia...        Chicago
# CAT     Caterpillar Inc. manufactures and sells constr...      Deerfield
# CSCO    Cisco Systems, Inc. designs, manufactures, and...       San Jose
# CVX     Chevron Corporation, through its subsidiaries,...      San Ramon
# GS      The Goldman Sachs Group, Inc., a financial ins...       New York
# HD      The Home Depot, Inc. operates as a home improv...        Atlanta
# HON     Honeywell International Inc. operates as a div...      Charlotte
# IBM     International Business Machines Corporation pr...         Armonk
# INTC    Intel Corporation engages in the design, manuf...    Santa Clara
# JNJ     Johnson & Johnson, together with its subsidiar...  New Brunswick
# KO      The Coca-Cola Company, a beverage company, man...        Atlanta
# JPM     JPMorgan Chase & Co. operates as a financial s...       New York
# MCD     McDonald's Corporation operates and franchises...        Chicago
# MMM     3M Company operates as a diversified technolog...     Saint Paul
# MRK     Merck & Co., Inc. operates as a healthcare com...     Kenilworth
# MSFT    Microsoft Corporation develops, licenses, and ...        Redmond
# NKE     NIKE, Inc., together with its subsidiaries, de...      Beaverton
# PG      The Procter & Gamble Company provides branded ...     Cincinnati
# TRV     The Travelers Companies, Inc., through its sub...       New York
# UNH     UnitedHealth Group Incorporated operates as a ...     Minnetonka
# CRM     Salesforce, Inc. provides customer relationshi...  San Francisco
# VZ      Verizon Communications Inc., through its subsi...       New York
# V       Visa Inc. operates as a payments technology co...  San Francisco
# WBA     Walgreens Boots Alliance, Inc. operates as a p...      Deerfield
# WMT     Walmart Inc. engages in the operation of retai...    Bentonville
# DIS     The Walt Disney Company, together with its sub...        Burbank
# DOW     Dow Inc. provides various materials science so...        Midland
#
#                phone state        country companyOfficers  \
# symbol
# AXP     212 640 2000    NY  United States              []
# AMGN    805 447 1000    CA  United States              []
# AAPL    408 996 1010    CA  United States              []
# BA      312 544 2000    IL  United States              []
# CAT     224-551-4000    IL  United States              []
# CSCO    408 526 4000    CA  United States              []
# CVX     925 842 1000    CA  United States              []
# GS      212-902-1000    NY  United States              []
# HD      770 433 8211    GA  United States              []
# HON     704 627 6200    NC  United States              []
# IBM     914 499 1900    NY  United States              []
# INTC    408 765 8080    CA  United States              []
# JNJ     732 524 0400    NJ  United States              []
# KO      404 676 2121    GA  United States              []
# JPM     212 270 6000    NY  United States              []
# MCD     630 623 3000    IL  United States              []
# MMM     651 733 1110    MN  United States              []
# MRK     908 740 4000    NJ  United States              []
# MSFT    425 882 8080    WA  United States              []
# NKE     503 671 6453    OR  United States              []
# PG      513 983 1100    OH  United States              []
# TRV     917 778 6000    NY  United States              []
# UNH     952 936 1300    MN  United States              []
# CRM     415 901 7000    CA  United States              []
# VZ      212 395 1000    NY  United States              []
# V       650 432 3200    CA  United States              []
# WBA     847 315 3700    IL  United States              []
# WMT     479 273 4000    AR  United States              []
# DIS     818 560 1000    CA  United States              []
# DOW     989 636 1000    MI  United States              []
#
#                                        website  ...  regularMarketPrice  \
# symbol                                          ...
# AXP            https://www.americanexpress.com  ...            157.3900
# AMGN                     https://www.amgen.com  ...            246.1300
# AAPL                     https://www.apple.com  ...            164.9400
# BA                      https://www.boeing.com  ...            164.7813
# CAT                https://www.caterpillar.com  ...            185.5400
# CSCO                     https://www.cisco.com  ...             44.8888
# CVX                    https://www.chevron.com  ...            154.3800
# GS                https://www.goldmansachs.com  ...            334.9500
# HD                   https://www.homedepot.com  ...            308.4850
# HON                  https://www.honeywell.com  ...            192.1019
# IBM                        https://www.ibm.com  ...            132.1700
# INTC                     https://www.intel.com  ...             35.2850
# JNJ                        https://www.jnj.com  ...            171.1600
# KO            https://www.coca-colacompany.com  ...             63.0700
# JPM              https://www.jpmorganchase.com  ...            116.0000
# MCD            https://corporate.mcdonalds.com  ...            258.5300
# MMM                         https://www.3m.com  ...            147.4350
# MRK                      https://www.merck.com  ...             87.1900
# MSFT                 https://www.microsoft.com  ...            282.3700
# NKE                 https://investors.nike.com  ...            113.6256
# PG                  https://www.pginvestor.com  ...            143.9700
# TRV                  https://www.travelers.com  ...            159.0500
# UNH          https://www.unitedhealthgroup.com  ...            531.3475
# CRM                 https://www.salesforce.com  ...            189.9650
# VZ                     https://www.verizon.com  ...             44.8200
# V                         https://usa.visa.com  ...            214.4700
# WBA     https://www.walgreensbootsalliance.com  ...             38.8350
# WMT              https://www.stock.walmart.com  ...            125.4900
# DIS       https://www.thewaltdisneycompany.com  ...            106.6907
# DOW                        https://www.dow.com  ...             51.3750
#
#        preMarketPrice                                           logo_url  \
# symbol
# AXP           156.730      https://logo.clearbit.com/americanexpress.com
# AMGN          246.000                https://logo.clearbit.com/amgen.com
# AAPL          163.000                https://logo.clearbit.com/apple.com
# BA            164.240               https://logo.clearbit.com/boeing.com
# CAT           183.640          https://logo.clearbit.com/caterpillar.com
# CSCO           44.800                https://logo.clearbit.com/cisco.com
# CVX           149.080              https://logo.clearbit.com/chevron.com
# GS            331.560         https://logo.clearbit.com/goldmansachs.com
# HD            305.000            https://logo.clearbit.com/homedepot.com
# HON           190.250            https://logo.clearbit.com/honeywell.com
# IBM           131.210                  https://logo.clearbit.com/ibm.com
# INTC           35.360                https://logo.clearbit.com/intel.com
# JNJ           171.400                  https://logo.clearbit.com/jnj.com
# KO             63.810     https://logo.clearbit.com/coca-colacompany.com
# JPM           112.600        https://logo.clearbit.com/jpmorganchase.com
# MCD           258.849  https://logo.clearbit.com/corporate.mcdonalds.com
# MMM           147.300                   https://logo.clearbit.com/3m.com
# MRK            86.230                https://logo.clearbit.com/merck.com
# MSFT          279.130            https://logo.clearbit.com/microsoft.com
# NKE           112.970       https://logo.clearbit.com/investors.nike.com
# PG            144.050           https://logo.clearbit.com/pginvestor.com
# TRV           157.700            https://logo.clearbit.com/travelers.com
# UNH           533.750    https://logo.clearbit.com/unitedhealthgroup.com
# CRM           187.360           https://logo.clearbit.com/salesforce.com
# VZ             44.430              https://logo.clearbit.com/verizon.com
# V             210.280             https://logo.clearbit.com/usa.visa.com
# WBA            38.980  https://logo.clearbit.com/walgreensbootsallian...
# WMT           125.500        https://logo.clearbit.com/stock.walmart.com
# DIS           106.870  https://logo.clearbit.com/thewaltdisneycompany...
# DOW            50.580                  https://logo.clearbit.com/dow.com
#
#         trailingPegRatio           fax                      address2  \
# symbol
# AXP               1.3560           NaN                           NaN
# AMGN              1.4832  805 447 1010                           NaN
# AAPL              2.9709           NaN                           NaN
# BA                6.5305           NaN                           NaN
# CAT               1.4547           NaN                     Suite 100
# CSCO              2.2976           NaN                           NaN
# CVX               2.2028           NaN                           NaN
# GS                   NaN           NaN                           NaN
# HD                2.6173           NaN                           NaN
# HON               1.9560           NaN                           NaN
# IBM               1.7929           NaN                           NaN
# INTC              4.8047           NaN                           NaN
# JNJ               4.0508           NaN                           NaN
# KO                3.5643           NaN                           NaN
# JPM                  NaN           NaN                           NaN
# MCD               3.7428           NaN                           NaN
# MMM               2.4144           NaN                           NaN
# MRK               1.1323           NaN                           NaN
# MSFT              2.1040  425 706 7329                           NaN
# NKE               2.4180           NaN                           NaN
# PG                4.4144           NaN                           NaN
# TRV                  NaN           NaN                           NaN
# UNH                  NaN           NaN           9900 Bren Road East
# CRM                  NaN  415 901 7040  3rd Floor 415 Mission Street
# VZ                   NaN           NaN                           NaN
# V                    NaN           NaN                           NaN
# WBA                  NaN           NaN                           NaN
# WMT                  NaN           NaN                           NaN
# DIS                  NaN           NaN                           NaN
# DOW                  NaN  989 832 1456                           NaN
#
#         underlyingSymbol  underlyingExchangeSymbol  headSymbol  \
# symbol
# AXP                  NaN                       NaN         NaN
# AMGN                 NaN                       NaN         NaN
# AAPL                 NaN                       NaN         NaN
# BA                   NaN                       NaN         NaN
# CAT                  NaN                       NaN         NaN
# CSCO                 NaN                       NaN         NaN
# CVX                  NaN                       NaN         NaN
# GS                   NaN                       NaN         NaN
# HD                   NaN                       NaN         NaN
# HON                  NaN                       NaN         NaN
# IBM                  NaN                       NaN         NaN
# INTC                 NaN                       NaN         NaN
# JNJ                  NaN                       NaN         NaN
# KO                   NaN                       NaN         NaN
# JPM                  NaN                       NaN         NaN
# MCD                  NaN                       NaN         NaN
# MMM                  NaN                       NaN         NaN
# MRK                  NaN                       NaN         NaN
# MSFT                 NaN                       NaN         NaN
# NKE                  NaN                       NaN         NaN
# PG                   NaN                       NaN         NaN
# TRV                  NaN                       NaN         NaN
# UNH                  NaN                       NaN         NaN
# CRM                  NaN                       NaN         NaN
# VZ                   NaN                       NaN         NaN
# V                    NaN                       NaN         NaN
# WBA                  NaN                       NaN         NaN
# WMT                  NaN                       NaN         NaN
# DIS                  NaN                       NaN         NaN
# DOW                  NaN                       NaN         NaN
#
#                                         uuid
# symbol
# AXP                                      NaN
# AMGN                                     NaN
# AAPL                                     NaN
# BA                                       NaN
# CAT                                      NaN
# CSCO                                     NaN
# CVX                                      NaN
# GS                                       NaN
# HD                                       NaN
# HON                                      NaN
# IBM                                      NaN
# INTC                                     NaN
# JNJ                                      NaN
# KO                                       NaN
# JPM                                      NaN
# MCD                                      NaN
# MMM                                      NaN
# MRK                                      NaN
# MSFT                                     NaN
# NKE                                      NaN
# PG                                       NaN
# TRV                                      NaN
# UNH     33ae4437-560d-3a42-9aa4-234d48c993c5
# CRM     01d3fcca-fdd3-37b7-b601-1bfd3a695ce7
# VZ      a708480c-0400-3ea0-b2d3-ca752db5c3b1
# V       5206560a-306a-3e08-9a43-7fd258eb57ce
# WBA                                      NaN
# WMT     902d429a-38af-3903-a1d7-3374c3560928
# DIS     aef70f8f-79be-3478-9d04-39acf5bad0ef
# DOW     9510e206-86db-3ea5-bd8f-fbd901232728
#
# [30 rows x 159 columns]

# %%
test = fundamental_info_df[['beta', 'marketCap', 'forwardPE', 'dividendYield']]
test

# %%
display(test.beta.plot(kind='bar'));
display(test.beta.nlargest(5));
display(test.beta.nsmallest(5));
# Out:
# <AxesSubplot:xlabel='symbol'>
# symbol
# DOW     1.406411
# GS      1.385929
# BA      1.367816
# DIS     1.237122
# AAPL    1.230174
# Name: beta, dtype: float64
# symbol
# MRK    0.324928
# PG     0.342822
# VZ     0.383567
# WMT    0.522349
# KO     0.557684
# Name: beta, dtype: float64

# %%
display(test.marketCap.plot(kind='bar'))
display(test.marketCap.nlargest(5));
display(test.marketCap.nsmallest(5));
# Out:
# <AxesSubplot:xlabel='symbol'>
# symbol
# AAPL    2.650718e+12
# MSFT    2.105884e+12
# UNH     5.004502e+11
# JNJ     4.500104e+11
# WMT     3.480942e+11
# Name: marketCap, dtype: float64
# symbol
# WBA    3.356342e+10
# TRV    3.784515e+10
# DOW    3.799767e+10
# MMM    8.397956e+10
# BA     9.784895e+10
# Name: marketCap, dtype: float64

# %%
display(test.forwardPE.plot(kind='bar'))
display(test.forwardPE.nlargest(5));
display(test.forwardPE.nsmallest(5));
# Out:
# <AxesSubplot:xlabel='symbol'>
# symbol
# CRM     40.332270
# BA      39.515896
# AAPL    25.651634
# NKE     24.755032
# UNH     24.542608
# Name: forwardPE, dtype: float64
# symbol
# DOW    8.052507
# VZ     8.300000
# WBA    8.315846
# GS     8.679710
# JPM    9.228322
# Name: forwardPE, dtype: float64

# %%
display(test.dividendYield.plot(kind='bar'))
display(test.dividendYield.nlargest(5));
display(test.dividendYield.nsmallest(5));
# Out:
# <AxesSubplot:xlabel='symbol'>
# symbol
# VZ     0.0554
# DOW    0.0526
# IBM    0.0499
# WBA    0.0490
# MMM    0.0415
# Name: dividendYield, dtype: float64
# symbol
# AAPL    0.0055
# V       0.0071
# MSFT    0.0088
# NKE     0.0107
# UNH     0.0122
# Name: dividendYield, dtype: float64

# %%
for i in fundamental_info_df.columns:
    print(i)
# Out:
# zip
# sector
# fullTimeEmployees
# longBusinessSummary
# city
# phone
# state
# country
# companyOfficers
# website
# maxAge
# address1
# industry
# ebitdaMargins
# profitMargins
# grossMargins
# operatingCashflow
# revenueGrowth
# operatingMargins
# ebitda
# targetLowPrice
# recommendationKey
# grossProfits
# freeCashflow
# targetMedianPrice
# currentPrice
# earningsGrowth
# currentRatio
# returnOnAssets
# numberOfAnalystOpinions
# targetMeanPrice
# debtToEquity
# returnOnEquity
# targetHighPrice
# totalCash
# totalDebt
# totalRevenue
# totalCashPerShare
# financialCurrency
# revenuePerShare
# quickRatio
# recommendationMean
# exchange
# shortName
# longName
# exchangeTimezoneName
# exchangeTimezoneShortName
# isEsgPopulated
# gmtOffSetMilliseconds
# quoteType
# messageBoardId
# market
# annualHoldingsTurnover
# enterpriseToRevenue
# beta3Year
# enterpriseToEbitda
# 52WeekChange
# morningStarRiskRating
# forwardEps
# revenueQuarterlyGrowth
# sharesOutstanding
# fundInceptionDate
# annualReportExpenseRatio
# totalAssets
# bookValue
# sharesShort
# sharesPercentSharesOut
# fundFamily
# lastFiscalYearEnd
# heldPercentInstitutions
# netIncomeToCommon
# trailingEps
# lastDividendValue
# SandP52WeekChange
# priceToBook
# heldPercentInsiders
# nextFiscalYearEnd
# yield
# mostRecentQuarter
# shortRatio
# sharesShortPreviousMonthDate
# floatShares
# beta
# enterpriseValue
# priceHint
# threeYearAverageReturn
# lastSplitDate
# lastSplitFactor
# legalType
# lastDividendDate
# morningStarOverallRating
# earningsQuarterlyGrowth
# priceToSalesTrailing12Months
# dateShortInterest
# pegRatio
# ytdReturn
# forwardPE
# lastCapGain
# shortPercentOfFloat
# sharesShortPriorMonth
# impliedSharesOutstanding
# category
# fiveYearAverageReturn
# previousClose
# regularMarketOpen
# twoHundredDayAverage
# trailingAnnualDividendYield
# payoutRatio
# volume24Hr
# regularMarketDayHigh
# navPrice
# averageDailyVolume10Day
# regularMarketPreviousClose
# fiftyDayAverage
# trailingAnnualDividendRate
# open
# toCurrency
# averageVolume10days
# expireDate
# algorithm
# dividendRate
# exDividendDate
# circulatingSupply
# startDate
# regularMarketDayLow
# currency
# trailingPE
# regularMarketVolume
# lastMarket
# maxSupply
# openInterest
# marketCap
# volumeAllCurrencies
# strikePrice
# averageVolume
# dayLow
# ask
# askSize
# volume
# fiftyTwoWeekHigh
# fromCurrency
# fiveYearAvgDividendYield
# fiftyTwoWeekLow
# bid
# tradeable
# dividendYield
# bidSize
# dayHigh
# coinMarketCapLink
# regularMarketPrice
# preMarketPrice
# logo_url
# trailingPegRatio
# fax
# address2
# underlyingSymbol
# underlyingExchangeSymbol
# headSymbol
# uuid

# %% [markdown]
# # Example to view on a micro scale (DELETE THIS PIECE, NOT NEEDED!)

# %%
msft = yf.Ticker("MSFT").info
msft

# do nlp word cloud on long business summary

# make companys logo a nft using their link.
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 221000,
#  'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. The More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; and Windows Internet of Things. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.',
#  'city': 'Redmond',
#  'phone': '425 882 8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'fax': '425 706 7329',
#  'industry': 'Software—Infrastructure',
#  'ebitdaMargins': 0.49418998,
#  'profitMargins': 0.36686,
#  'grossMargins': 0.68402,
#  'operatingCashflow': 89034997760,
#  'revenueGrowth': 0.124,
#  'operatingMargins': 0.42055,
#  'ebitda': 97982996480,
#  'targetLowPrice': 275,
#  'recommendationKey': 'buy',
#  'grossProfits': 135620000000,
#  'freeCashflow': 49479000064,
#  'targetMedianPrice': 330,
#  'currentPrice': 281.92,
#  'earningsGrowth': 0.031,
#  'currentRatio': 1.785,
#  'returnOnAssets': 0.14919,
#  'numberOfAnalystOpinions': 46,
#  'targetMeanPrice': 336.82,
#  'debtToEquity': 47.075,
#  'returnOnEquity': 0.47151002,
#  'targetHighPrice': 411,
#  'totalCash': 104748998656,
#  'totalDebt': 78399995904,
#  'totalRevenue': 198269992960,
#  'totalCashPerShare': 14.045,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 26.45,
#  'quickRatio': 1.567,
#  'recommendationMean': 1.7,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 10.537,
#  'beta3Year': None,
#  'enterpriseToEbitda': 21.321,
#  '52WeekChange': -0.020071864,
#  'morningStarRiskRating': None,
#  'forwardEps': 12.11,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7457889792,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 22.313,
#  'sharesShort': 38999356,
#  'sharesPercentSharesOut': 0.0052,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1656547200,
#  'heldPercentInstitutions': 0.72111,
#  'netIncomeToCommon': 72737996800,
#  'trailingEps': 9.69,
#  'lastDividendValue': 0.62,
#  'SandP52WeekChange': -0.06414485,
#  'priceToBook': 12.634788,
#  'heldPercentInsiders': 0.00075,
#  'nextFiscalYearEnd': 1719705600,
#  'yield': None,
#  'mostRecentQuarter': 1656547200,
#  'shortRatio': 1.42,
#  'sharesShortPreviousMonthDate': 1655251200,
#  'floatShares': 7450881454,
#  'beta': 0.927206,
#  'enterpriseValue': 2089082028032,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1652832000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.017,
#  'priceToSalesTrailing12Months': 10.60437,
#  'dateShortInterest': 1657843200,
#  'pegRatio': 1.77,
#  'ytdReturn': None,
#  'forwardPE': 23.279936,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0052,
#  'sharesShortPriorMonth': 48150433,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 283.65,
#  'regularMarketOpen': 279.15,
#  'twoHundredDayAverage': 295.2558,
#  'trailingAnnualDividendYield': 0.00874317,
#  'payoutRatio': 0.2508,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 283.65,
#  'navPrice': None,
#  'averageDailyVolume10Day': 27975910,
#  'regularMarketPreviousClose': 283.65,
#  'fiftyDayAverage': 262.917,
#  'trailingAnnualDividendRate': 2.48,
#  'open': 279.15,
#  'toCurrency': None,
#  'averageVolume10days': 27975910,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.48,
#  'exDividendDate': 1660694400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 278.68,
#  'currency': 'USD',
#  'trailingPE': 29.093914,
#  'regularMarketVolume': 12274956,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2102528442368,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 29791038,
#  'dayLow': 278.68,
#  'ask': 281.67,
#  'askSize': 1300,
#  'volume': 12274956,
#  'fiftyTwoWeekHigh': 349.67,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.23,
#  'fiftyTwoWeekLow': 241.51,
#  'bid': 281.67,
#  'tradeable': False,
#  'dividendYield': 0.0088,
#  'bidSize': 900,
#  'dayHigh': 283.65,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 281.92,
#  'preMarketPrice': 279.13,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com',
#  'trailingPegRatio': 2.104}

# %%
numshares = msft.info['sharesOutstanding']
numshares
# Out:
# 7457889792

# %%
fundamental_dictionary_df = pd.DataFrame.from_dict(fundamental_dictionary)
fundamental_dictionary_df.columns
# Out:
# Index(['zip', 'sector', 'fullTimeEmployees', 'longBusinessSummary', 'city',
#        'phone', 'state', 'country', 'companyOfficers', 'website',
#        ...
#        'bid', 'tradeable', 'dividendYield', 'bidSize', 'dayHigh',
#        'coinMarketCapLink', 'regularMarketPrice', 'preMarketPrice', 'logo_url',
#        'trailingPegRatio'],
#       dtype='object', length=155)

# %%
fundamental_list_df = ('zip', 'sector', 'fullTimeEmployees', 'longBusinessSummary', 
                       'city', 'phone', 'state', 'country', 'companyOfficers', 
                       'website', 'maxAge', 'address1', 'fax', 'industry', 
                       'ebitdaMargins', 'profitMargins', 'grossMargins', 
                       'operatingCashflow', 'revenueGrowth', 'operatingMargins', 
                       'ebitda', 'targetLowPrice', 'recommendationKey', 
                       'grossProfits', 'freeCashflow', 'targetMedianPrice', 
                       'currentPrice', 'earningsGrowth', 'currentRatio', 'returnOnAssets', 
                       'numberOfAnalystOpinions', 'targetMeanPrice', 'debtToEquity', 
                       'returnOnEquity', 'targetHighPrice', 'totalCash', 'totalDebt', 
                       'totalRevenue', 'totalCashPerShare', 'financialCurrency', 
                       'revenuePerShare', 'quickRatio', 'recommendationMean', 'exchange', 
                       'shortName', 'longName', 'exchangeTimezoneName', 
                       'exchangeTimezoneShortName', 'isEsgPopulated', 'gmtOffSetMilliseconds', 
                       'quoteType', 'symbol', 'messageBoardId', 'market', 'annualHoldingsTurnover', 
                       'enterpriseToRevenue', 'beta3Year', 'enterpriseToEbitda', '52WeekChange', 
                       'morningStarRiskRating', 'forwardEps', 'revenueQuarterlyGrowth', 
                       'sharesOutstanding', 'fundInceptionDate', 'annualReportExpenseRatio', 
                       'totalAssets', 'bookValue', 'sharesShort', 'sharesPercentSharesOut', 
                       'fundFamily', 'lastFiscalYearEnd', 'heldPercentInstitutions', 
                       'netIncomeToCommon', 'trailingEps', 'lastDividendValue', 
                       'SandP52WeekChange', 'priceToBook', 'heldPercentInsiders', 
                       'nextFiscalYearEnd', 'yield', 'mostRecentQuarter', 'shortRatio', 
                       'sharesShortPreviousMonthDate', 'floatShares', 'beta', 'enterpriseValue', 
                       'priceHint', 'threeYearAverageReturn', 'lastSplitDate', 'lastSplitFactor', 
                       'legalType', 'lastDividendDate', 'morningStarOverallRating', 
                       'earningsQuarterlyGrowth', 'priceToSalesTrailing12Months', 'dateShortInterest', 
                       'pegRatio', 'ytdReturn', 'forwardPE', 'lastCapGain', 'shortPercentOfFloat', 
                       'sharesShortPriorMonth', 'impliedSharesOutstanding', 'category', 
                       'fiveYearAverageReturn', 'previousClose', 'regularMarketOpen', 
                       'twoHundredDayAverage', 'trailingAnnualDividendYield', 'payoutRatio', 
                       'volume24Hr', 'regularMarketDayHigh', 'navPrice', 'averageDailyVolume10Day', 
                       'regularMarketPreviousClose', 'fiftyDayAverage', 'trailingAnnualDividendRate', 
                       'open', 'toCurrency', 'averageVolume10days', 'expireDate', 'algorithm', 
                       'dividendRate', 'exDividendDate', 'circulatingSupply', 'startDate', 
                       'regularMarketDayLow', 'currency', 'trailingPE', 'regularMarketVolume', 
                       'lastMarket', 'maxSupply', 'openInterest', 'marketCap', 'volumeAllCurrencies', 
                       'strikePrice', 'averageVolume', 'dayLow', 'ask', 'askSize', 'volume', 
                       'fiftyTwoWeekHigh', 'fromCurrency', 'fiveYearAvgDividendYield', 
                       'fiftyTwoWeekLow', 'bid', 'tradeable', 'dividendYield', 'bidSize', 'dayHigh',
                       'coinMarketCapLink', 'regularMarketPrice', 'preMarketPrice', 'logo_url', 
                       'trailingPegRatio')

# %%
# Out:
# ('zip',
#  'sector',
#  'fullTimeEmployees',
#  'longBusinessSummary',
#  'city',
#  'phone',
#  'state',
#  'country',
#  'companyOfficers',
#  'website',
#  'maxAge',
#  'address1',
#  'fax',
#  'industry',
#  'ebitdaMargins',
#  'profitMargins',
#  'grossMargins',
#  'operatingCashflow',
#  'revenueGrowth',
#  'operatingMargins',
#  'ebitda',
#  'targetLowPrice',
#  'recommendationKey',
#  'grossProfits',
#  'freeCashflow',
#  'targetMedianPrice',
#  'currentPrice',
#  'earningsGrowth',
#  'currentRatio',
#  'returnOnAssets',
#  'numberOfAnalystOpinions',
#  'targetMeanPrice',
#  'debtToEquity',
#  'returnOnEquity',
#  'targetHighPrice',
#  'totalCash',
#  'totalDebt',
#  'totalRevenue',
#  'totalCashPerShare',
#  'financialCurrency',
#  'revenuePerShare',
#  'quickRatio',
#  'recommendationMean',
#  'exchange',
#  'shortName',
#  'longName',
#  'exchangeTimezoneName',
#  'exchangeTimezoneShortName',
#  'isEsgPopulated',
#  'gmtOffSetMilliseconds',
#  'quoteType',
#  'symbol',
#  'messageBoardId',
#  'market',
#  'annualHoldingsTurnover',
#  'enterpriseToRevenue',
#  'beta3Year',
#  'enterpriseToEbitda',
#  '52WeekChange',
#  'morningStarRiskRating',
#  'forwardEps',
#  'revenueQuarterlyGrowth',
#  'sharesOutstanding',
#  'fundInceptionDate',
#  'annualReportExpenseRatio',
#  'totalAssets',
#  'bookValue',
#  'sharesShort',
#  'sharesPercentSharesOut',
#  'fundFamily',
#  'lastFiscalYearEnd',
#  'heldPercentInstitutions',
#  'netIncomeToCommon',
#  'trailingEps',
#  'lastDividendValue',
#  'SandP52WeekChange',
#  'priceToBook',
#  'heldPercentInsiders',
#  'nextFiscalYearEnd',
#  'yield',
#  'mostRecentQuarter',
#  'shortRatio',
#  'sharesShortPreviousMonthDate',
#  'floatShares',
#  'beta',
#  'enterpriseValue',
#  'priceHint',
#  'threeYearAverageReturn',
#  'lastSplitDate',
#  'lastSplitFactor',
#  'legalType',
#  'lastDividendDate',
#  'morningStarOverallRating',
#  'earningsQuarterlyGrowth',
#  'priceToSalesTrailing12Months',
#  'dateShortInterest',
#  'pegRatio',
#  'ytdReturn',
#  'forwardPE',
#  'lastCapGain',
#  'shortPercentOfFloat',
#  'sharesShortPriorMonth',
#  'impliedSharesOutstanding',
#  'category',
#  'fiveYearAverageReturn',
#  'previousClose',
#  'regularMarketOpen',
#  'twoHundredDayAverage',
#  'trailingAnnualDividendYield',
#  'payoutRatio',
#  'volume24Hr',
#  'regularMarketDayHigh',
#  'navPrice',
#  'averageDailyVolume10Day',
#  'regularMarketPreviousClose',
#  'fiftyDayAverage',
#  'trailingAnnualDividendRate',
#  'open',
#  'toCurrency',
#  'averageVolume10days',
#  'expireDate',
#  'algorithm',
#  'dividendRate',
#  'exDividendDate',
#  'circulatingSupply',
#  'startDate',
#  'regularMarketDayLow',
#  'currency',
#  'trailingPE',
#  'regularMarketVolume',
#  'lastMarket',
#  'maxSupply',
#  'openInterest',
#  'marketCap',
#  'volumeAllCurrencies',
#  'strikePrice',
#  'averageVolume',
#  'dayLow',
#  'ask',
#  'askSize',
#  'volume',
#  'fiftyTwoWeekHigh',
#  'fromCurrency',
#  'fiveYearAvgDividendYield',
#  'fiftyTwoWeekLow',
#  'bid',
#  'tradeable',
#  'dividendYield',
#  'bidSize',
#  'dayHigh',
#  'coinMarketCapLink',
#  'regularMarketPrice',
#  'preMarketPrice',
#  'logo_url',
#  'trailingPegRatio')
